# %%
import networkx as nx

# %%
G1 = nx.read_graphml('Exploratory/Nauty/results/filtered_woodgraphs_graphml/filtered_woodgraphs.graphml')
G2 = nx.read_graphml('Exploratory/Nauty/results/generated_graphs_n16_graphml/generated_graphs_n16.graphml')
print(nx.is_isomorphic(G1, G2))
print(nx.is_strongly_regular(G1))
# its the Clebsch graph, https://en.wikipedia.org/wiki/Clebsch_graph
# Out:
# True
# True
